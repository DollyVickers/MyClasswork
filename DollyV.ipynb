# %%
# Dependencies and Setup
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import datetime
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
new_cities=[]
cloudiness=[]
country=[]
date=[]
humidity=[]
temp=[]
lat=[]
lng=[]
wind=[]

# %%
record_counter=0
set_counter=0
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
print('-----------------------')
print('Beginning Data Retrieval')
print('-----------------------')

for city in cities:
    query_url=url + "&q=" + city
    #Get weather data
    response=requests.get(query_url).json()
    if record_counter<50:
        record_counter +=1
    else:
        set_counter +=1
        record_counter=0
        
    print('Processing record {} of set {} |{}'.format(record_counter, set_counter, city))
    print(url)

    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
                     
    except:
        print("City not found!")
        pass
                          
print('------------------------')
print('Data Retrieval Complete')
print('------------------------')
# Out:
# -----------------------
# Beginning Data Retrieval
# -----------------------
# Processing record 1 of set 0 |muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 2 of set 0 |hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 3 of set 0 |kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 4 of set 0 |tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 5 of set 0 |atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 6 of set 0 |teguise
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 7 of set 0 |fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 8 of set 0 |catamarca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# City not found!
# Processing record 9 of set 0 |avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 10 of set 0 |barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 11 of set 0 |busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 12 of set 0 |rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 13 of set 0 |yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 14 of set 0 |mrirt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# City not found!
# Processing record 15 of set 0 |ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 16 of set 0 |juegang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 17 of set 0 |lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 18 of set 0 |jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 19 of set 0 |nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 20 of set 0 |pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 21 of set 0 |geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 22 of set 0 |astana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 23 of set 0 |taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# City not found!
# Processing record 24 of set 0 |punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 25 of set 0 |atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 26 of set 0 |faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 27 of set 0 |pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 28 of set 0 |ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 29 of set 0 |saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 30 of set 0 |ciudad bolivar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 31 of set 0 |kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 32 of set 0 |saravan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 33 of set 0 |ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 34 of set 0 |kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 35 of set 0 |bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 36 of set 0 |hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 37 of set 0 |longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 38 of set 0 |egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 39 of set 0 |akyab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# City not found!
# Processing record 40 of set 0 |castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 41 of set 0 |thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 42 of set 0 |hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 43 of set 0 |cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 44 of set 0 |belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# City not found!
# Processing record 45 of set 0 |teguldet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 46 of set 0 |bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 47 of set 0 |port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 48 of set 0 |lebanon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 49 of set 0 |grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 50 of set 0 |russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 0 of set 1 |aguachica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 1 of set 1 |abu kamal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 2 of set 1 |albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 3 of set 1 |attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# City not found!
# Processing record 4 of set 1 |vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 5 of set 1 |aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 6 of set 1 |iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 7 of set 1 |dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 8 of set 1 |arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 9 of set 1 |carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 10 of set 1 |mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 11 of set 1 |mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# City not found!
# Processing record 12 of set 1 |illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# City not found!
# Processing record 13 of set 1 |tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 14 of set 1 |dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 15 of set 1 |tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 16 of set 1 |khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 17 of set 1 |denton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 18 of set 1 |urdoma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 19 of set 1 |ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 20 of set 1 |qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 21 of set 1 |portree
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 22 of set 1 |nsanje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 23 of set 1 |alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 24 of set 1 |tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 25 of set 1 |meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 26 of set 1 |butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 27 of set 1 |poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 28 of set 1 |havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 29 of set 1 |peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 30 of set 1 |alice
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 31 of set 1 |new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 32 of set 1 |lucea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 33 of set 1 |howard springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 34 of set 1 |mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 35 of set 1 |east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 36 of set 1 |airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 37 of set 1 |san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 38 of set 1 |sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 39 of set 1 |fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 40 of set 1 |namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 41 of set 1 |codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 42 of set 1 |sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 43 of set 1 |clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 44 of set 1 |itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 45 of set 1 |beni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 46 of set 1 |cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 47 of set 1 |saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 48 of set 1 |atocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 49 of set 1 |tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 50 of set 1 |bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 0 of set 2 |kita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 1 of set 2 |vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# City not found!
# Processing record 2 of set 2 |oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 3 of set 2 |faridabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 4 of set 2 |pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 5 of set 2 |carauari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 6 of set 2 |kenora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 7 of set 2 |teacapan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 8 of set 2 |souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 9 of set 2 |chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 10 of set 2 |hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 11 of set 2 |kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 12 of set 2 |sulina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# City not found!
# Processing record 13 of set 2 |mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 14 of set 2 |stepnyak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 15 of set 2 |narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 35 of set 10 |kalundborg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 36 of set 10 |thunder bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 37 of set 10 |labutta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# City not found!
# Processing record 38 of set 10 |morant bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 39 of set 10 |turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 40 of set 10 |akdagmadeni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 41 of set 10 |grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 42 of set 10 |halifax
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 43 of set 10 |megion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 44 of set 10 |rajur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 45 of set 10 |balaipungut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 46 of set 10 |majholi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 47 of set 10 |pedernales
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 48 of set 10 |puerto madryn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 49 of set 10 |ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 50 of set 10 |nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 0 of set 11 |novo aripuana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 1 of set 11 |acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 2 of set 11 |altonia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# City not found!
# Processing record 3 of set 11 |natal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 4 of set 11 |madimba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 5 of set 11 |tambopata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# City not found!
# Processing record 6 of set 11 |poya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 7 of set 11 |plover
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 8 of set 11 |tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 9 of set 11 |aksu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 10 of set 11 |mokhsogollokh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 11 of set 11 |karlskoga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 12 of set 11 |yangshan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 13 of set 11 |kluang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 14 of set 11 |nurota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 15 of set 11 |elizabeth city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 16 of set 11 |ossora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 17 of set 11 |guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 18 of set 11 |ewo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 19 of set 11 |port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 20 of set 11 |henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 21 of set 11 |auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 22 of set 11 |evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 23 of set 11 |gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 24 of set 11 |loncoche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 25 of set 11 |goksun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 26 of set 11 |samalaeulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# City not found!
# Processing record 27 of set 11 |koupela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 28 of set 11 |fujin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 29 of set 11 |antalaha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 30 of set 11 |urumqi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# City not found!
# Processing record 31 of set 11 |yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 32 of set 11 |ozgon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# City not found!
# Processing record 33 of set 11 |bluefield
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 34 of set 11 |haapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# City not found!
# Processing record 35 of set 11 |naranjal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 36 of set 11 |lingyuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 37 of set 11 |kerman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 38 of set 11 |les cayes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 39 of set 11 |americo brasiliense
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 40 of set 11 |flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 41 of set 11 |green valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# Processing record 42 of set 11 |orocue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=02688bd1751a567e4336ff249ee4fa59
# ------------------------
# Data Retrieval Complete
# ------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create a data frame from cities, temp, humidity, cloudiness and wind speed
weather_dict= {
    "City":new_cities,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Temp": temp,
    "Lat": lat,
    "Lng": lng,
    "Wind Speed": wind
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          546
# Cloudiness    546
# Country       546
# Date          546
# Humidity      546
# Temp          546
# Lat           546
# Lng           546
# Wind Speed    546
# dtype: int64

# %%
weather_data.to_csv('weather.csv', index=False, header=None)

weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity   Temp    Lat  \
# 0         muros          40      ES  2019-02-27       100  52.00  42.77
# 1          hilo          90      US  2019-02-27        60  73.40  19.71
# 2  kruisfontein           0      ZA  2019-02-27        77  62.70 -34.00
# 3   tuktoyaktuk          20      CA  2019-02-27        77  -0.41  69.44
# 4          atar           0      MR  2019-02-27        17  63.51  20.52
#
#       Lng  Wind Speed
# 0   -9.06        5.82
# 1 -155.08       12.75
# 2   24.73       15.14
# 3 -133.03       17.22
# 4  -13.05       12.01

# %%
date = datetime.date.today()
date
datetime.date(2019, 2, 27)
# Out:
# datetime.date(2019, 2, 27)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather_data.plot(kind='scatter', x='Lat',y='Temp',c='DarkBlue')
plt.title('City Latitude Vs Max Temperature ({})'.format(date))
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()
plt.savefig("../Images/LatitudeVsTemperature.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
weather_data.plot(kind='scatter',x='Lat',y='Humidity',c='DarkBlue')
plt.title('City Latitude Vs Max Humidity ({})'.format(date))
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.savefig("../Images/LatitudeVsHumidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
weather_data.plot(kind='scatter',x='Lat',y='Cloudiness',c='DarkBlue')
plt.title('City Latitude Vs Cloudiness ({})'.format(date))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.grid()
plt.savefig("../Images/LatitudeVsCloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
weather_data.plot(kind='scatter',x='Lat',y='Wind Speed',c='DarkBlue')
plt.title('City Latitude Vs Wind Speed ({})'.format(date))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.savefig("../Images/LatitudeVsWindSpeed.png")
